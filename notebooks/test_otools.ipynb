# %%
import obsidiantools.api as otools

# %%
vault = otools.Vault("../../dsview_vault_test").connect()
vault.gather()

# %%
vault.backlinks_index
# Out:
# {'index': [],
#  'Automatic IDs None Defaults and Refreshing Data': [],
#  'SQLModel': [],
#  'Object Relational Mapping ORM': [],
#  'Database Transactions': [],
#  'Session Management': [],
#  'Data Expiration': []}

# %%
vault.get_backlinks("topics/Library/SQLModel")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 vault.get_backlinks("topics/Library/SQLModel")
#
# File ~/opt/anaconda3/envs/py311_dsview/lib/python3.11/site-packages/obsidiantools/api.py:852, in Vault.get_backlinks(self, note_name)
#     849     raise AttributeError('Connect notes before calling the function')
#     851 if note_name not in self._graph.nodes:
# --> 852     raise ValueError('"{}" not found in graph.'.format(note_name))
#     853 else:
#     854     return self._backlinks_index[note_name]
#
# ValueError: "topics/Library/SQLModel" not found in graph.

# %%
vault.get_backlinks("topics/Library/SQLModel")
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[68], line 1
#
# ----> 1 vault.get_backlinks("topics/Library/SQLModel")
#
#
#
# File ~/opt/anaconda3/envs/py311_dsview/lib/python3.11/site-packages/obsidiantools/api.py:852, in Vault.get_backlinks(self, note_name)
#
#     849     raise AttributeError('Connect notes before calling the function')
#
#     851 if note_name not in self._graph.nodes:
#
# --> 852     raise ValueError('"{}" not found in graph.'.format(note_name))
#
#     853 else:
#
#     854     return self._backlinks_index[note_name]
#
#
#
# ValueError: "topics/Library/SQLModel" not found in graph.

# %%
# Out:
# {'index': ['obsidian://open?vault=dsview_vault_test&file=Automatic%20IDs%20None%20Defaults%20and%20Refreshing%20Data'],
#  'Automatic IDs None Defaults and Refreshing Data': ['https://github.com/fastapi/sqlmodel',
#   'https://squidfunk.github.io/mkdocs-material/',
#   'https://medium.com/@tiangolo',
#   'https://tiangolo.com',
#   'https://dev.to/tiangolo'],
#  'SQLModel': [],
#  'Object Relational Mapping ORM': [],
#  'Database Transactions': [],
#  'Session Management': [],
#  'Data Expiration': []}

# %%
vault.md_file_index["SQLModel"].parent.name
# Out:
# 'Library'

# %%
select(InputContent).where()

# %%
vault.

# %%
# Out:
# {'index': {},
#  'Automatic IDs None Defaults and Refreshing Data': {'already_read': True,
#   'link': 'https://sqlmodel.tiangolo.com/tutorial/automatic-id-none-refresh/',
#   'read_priority': 1,
#   'source': 'The Batch',
#   'tags': ['Data_Engineering'],
#   'type': 'Content',
#   'upload_date': '2024-11-10'},
#  'SQLModel': {'date': '2024-11-10', 'type': 'Library'},
#  'Object Relational Mapping ORM': {'date': '2024-11-10', 'type': 'Concept'},
#  'Database Transactions': {'date': '2024-11-10', 'type': 'Concept'},
#  'Session Management': {'date': '2024-11-10', 'type': 'Concept'},
#  'Data Expiration': {'date': '2024-11-10', 'type': 'Concept'}}

# %%
vault.get_front_matter("SQLModel")["type"]
# Out:
# 'Library'

# %%
from sqlmodel import SQLModel, Field, create_engin, Session

# %%
engine = create_engine("sqlite:///../dsview.db")

# %%
with

# %%
vault.get_md_links("topics/Library/SQLModel")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 vault.get_md_links("topics/Library/SQLModel")
#
# File ~/opt/anaconda3/envs/py311_dsview/lib/python3.11/site-packages/obsidiantools/api.py:956, in Vault.get_md_links(self, file_name)
#     953     raise AttributeError('Connect notes before calling the function')
#     955 if file_name not in self._md_file_index:
# --> 956     raise ValueError('"{}" does not exist so it cannot have md links.'.format(file_name))
#     957 else:
#     958     return self._md_links_index[file_name]
#
# ValueError: "topics/Library/SQLModel" does not exist so it cannot have md links.

# %%
vault.md_links_index
# Out:
# {'index': ['obsidian://open?vault=dsview_vault_test&file=Automatic%20IDs%20None%20Defaults%20and%20Refreshing%20Data'],
#  'Automatic IDs None Defaults and Refreshing Data': ['https://github.com/fastapi/sqlmodel',
#   'https://squidfunk.github.io/mkdocs-material/',
#   'https://medium.com/@tiangolo',
#   'https://tiangolo.com',
#   'https://dev.to/tiangolo'],
#  'SQLModel': [],
#  'Object Relational Mapping ORM': [],
#  'Database Transactions': [],
#  'Session Management': [],
#  'Data Expiration': []}

# %%
vault.md_file_index
# Out:
# {'index': PosixPath('index.md'),
#  'Automatic IDs None Defaults and Refreshing Data': PosixPath('contents/Documentation/Automatic IDs None Defaults and Refreshing Data.md'),
#  'SQLModel': PosixPath('topics/Library/SQLModel.md'),
#  'Object Relational Mapping ORM': PosixPath('topics/Concept/Object Relational Mapping ORM.md'),
#  'Database Transactions': PosixPath('topics/Concept/Database Transactions.md'),
#  'Session Management': PosixPath('topics/Concept/Session Management.md'),
#  'Data Expiration': PosixPath('topics/Concept/Data Expiration.md')}

# %%
vault.gather().get_readable_text("SQLModel")
# Out:
# 'A library for interacting with databases using Python, built on top of SQLAlchemy.\n'

# %%
vault.get_readable_text("SQLModel")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 vault.get_readable_text("SQLModel")
#
# File ~/opt/anaconda3/envs/py311_dsview/lib/python3.11/site-packages/obsidiantools/api.py:1046, in Vault.get_readable_text(self, file_name)
#    1027 """Get readable text for a note (given its filename).
#    1028 This requires the vault function 'gather' to have been called.
#    1029
#    (...)
#    1043     str
#    1044 """
#    1045 if not self._is_gathered:
# -> 1046     raise AttributeError('Gather notes before calling the function')
#    1047 if file_name not in self._md_file_index:
#    1048     raise ValueError('"{}" does not exist so it cannot have text.'.format(file_name))
#
# AttributeError: Gather notes before calling the function

# %%
vault.get_backlink_counts("SQLModel")
# Out:
# {}

# %%
vault.get_backlinks("SQLModel")
# Out:
# []

# %%
vault.tags_index
# Out:
# {}

# %%
import regex as re

# %%
summary_content = "# Summary of Input Contents\n\n"
summary_content += "> Last updated on: 2024-11-09\n\n"

# %%
print(summary_content)
# Out:
# # Summary of Input Contents
#
# > Last updated on: 2024-11-09

# %%
re.sub("> Last updated on: [0-9]{4}-[0-9]{2}-[0-9]{2}T[0-9]\n\n", "> Last updated on: " + date.today().isoformat() + "\n\n", summary_content)
# Out:
# '# Summary of Input Contents\n\n> Last updated on: 2024-11-10\n\n'

# %%
[note](obsidian://open?vault=dsview_vault&file=AlphaTensor)

# %%
urllib.parse.quote("Bonjour fils dés putes")
# Out:
# 'Bonjour%20fils%20d%C3%A9s%20putes'

# %%
import urllib.parse

url = 'obsidian://open?'
params = {'vault': 'dsview_vault', 'file': "Reinforcement Learning"}
print(url + urllib.parse.urlencode(params))
# Out:
# obsidian://open?vault=dsview_vault&file=Reinforcement+Learning

# %%
from datetime import datetime

datetime.now().isoformat()
# Out:
# '2024-11-10T22:22:18.196934'

# %%
vault.md_file_index
# Out:
# {'summary': PosixPath('summary.md'),
#  'status': PosixPath('status.md'),
#  'GenAI Agents Repository': PosixPath('contents/Repository/GenAI Agents Repository.md'),
#  'OpenAI Swarm Framework': PosixPath('contents/Repository/OpenAI Swarm Framework.md'),
#  'Scientific Visualization with Python and Matplotlib': PosixPath('contents/Repository/Scientific Visualization with Python and Matplotlib.md'),
#  'BitNet: Inference Framework for 1-bit LLMs': PosixPath('contents/Repository/BitNet: Inference Framework for 1-bit LLMs.md'),
#  'Latent Scope: Investigating Latent Spaces': PosixPath('contents/Repository/Latent Scope: Investigating Latent Spaces.md'),
#  'Data Formulator: Create Rich Visualizations with AI': PosixPath('contents/Repository/Data Formulator: Create Rich Visualizations with AI.md'),
#  'PyGWalker: Interactive Data Visualization Tool': PosixPath('contents/Repository/PyGWalker: Interactive Data Visualization Tool.md'),
# ...
